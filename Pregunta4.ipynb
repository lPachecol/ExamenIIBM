# %%
import numpy as np
import matplotlib.pyplot as plt

xy = [
    (-7.0, 18.295), (-6.96, 18.924), (-6.92, 17.099), (-6.879, 19.592),
    (-6.839, 18.568), (-6.799, 16.477), (-6.759, 18.783), (-6.719, 18.082),
    (-6.678, 18.099), (-6.638, 16.696), (-6.598, 16.457), (-6.558, 15.253),
    (-6.518, 18.337), (-6.477, 17.179), (-6.437, 17.014), (-6.397, 16.393),
    (-6.357, 16.286), (-6.317, 14.595), (-6.276, 15.176), (-6.236, 14.259),
    (-6.196, 16.252), (-6.156, 14.637), (-6.116, 15.447), (-6.075, 15.911),
    (-6.035, 14.172), (-5.995, 15.924), (-5.955, 12.948), (-5.915, 14.402),
    (-5.874, 14.563), (-5.834, 16.175), (-5.794, 14.377), (-5.754, 14.59),
    (-5.714, 14.161), (-5.673, 13.727), (-5.633, 13.594), (-5.593, 14.123),
    (-5.553, 13.964), (-5.513, 12.951), (-5.472, 13.591), (-5.432, 13.893),
    (-5.392, 11.532), (-5.352, 14.877), (-5.312, 13.337), (-5.271, 13.795),
    (-5.231, 13.723), (-5.191, 13.589), (-5.151, 13.933), (-5.111, 13.801),
    (-5.07, 13.331), (-5.03, 13.001), (-4.99, 13.337), (-4.95, 13.225),
    (-4.91, 13.312), (-4.869, 13.716), (-4.829, 13.061), (-4.789, 12.933),
    (-4.749, 13.156), (-4.709, 14.092), (-4.668, 12.693), (-4.628, 12.263),
    (-4.588, 13.657), (-4.508, 12.131), (-4.467, 13.116), (-4.427, 11.28),
    (-4.387, 13.204), (-4.346, 12.183), (-4.306, 12.32), (-4.266, 14.183),
    (-4.226, 14.183), (-4.186, 13.632), (-4.106, 12.527), (-4.065, 12.806),
    (-4.025, 12.193), (-3.985, 13.291), (-3.945, 13.825), (-3.905, 13.929),
    (-3.864, 14.168), (-3.824, 14.39), (-3.784, 12.474), (-3.744, 14.265),
    (-3.704, 13.704), (-3.663, 13.912), (-3.623, 12.522), (-3.583, 14.085),
    (-3.543, 12.861), (-3.503, 14.924), (-3.462, 12.127), (-3.422, 12.428),
    (-3.382, 13.615), (-3.342, 13.042), (-3.302, 13.221), (-3.261, 14.469),
    (-3.181, 13.842), (-3.141, 13.583), (-3.101, 14.657), (-3.06, 14.469),
    (-3.02, 14.213), (-2.98, 16.623), (-2.94, 14.685), (-2.9, 14.229),
    (-2.859, 13.489), (-2.819, 15.049), (-2.779, 14.276), (-2.739, 16.734),
    (-2.698, 18.072), (-2.658, 16.275), (-2.618, 16.2), (-2.578, 14.893),
    (-2.538, 17.084), (-2.497, 15.674), (-2.457, 17.199), (-2.417, 15.14),
    (-2.377, 14.168), (-2.337, 15.705), (-2.297, 17.084), (-2.256, 17.176),
    (-2.216, 17.223), (-2.176, 15.501), (-2.136, 17.176), (-2.095, 16.294),
    (-2.055, 18.477), (-2.015, 17.223), (-1.975, 16.642), (-1.935, 19.196),
    (-1.894, 19.283), (-1.854, 20.629), (-1.814, 17.274), (-1.774, 18.177),
    (-1.734, 20.677), (-1.693, 20.113), (-1.653, 21.712), (-1.613, 20.691),
    (-1.573, 20.684), (-1.533, 19.898), (-1.493, 20.818), (-1.452, 19.164),
    (-1.412, 20.512), (-0.97, 27.049), (-0.93, 27.149), (-0.889, 26.742),
    (-0.849, 23.391), (-0.809, 22.793), (-0.769, 26.011), (-0.729, 26.685),
    (-0.688, 28.185), (-0.648, 28.486), (-0.608, 26.452), (-0.528, 31.528),
    (-0.487, 31.188), (-0.447, 29.722), (-0.407, 29.521), (-0.367, 30.92),
    (-0.327, 30.658), (-0.286, 31.168), (-0.246, 30.945), (-0.206, 32.173),
    (-0.166, 30.66), (-0.126, 36.273), (-0.085, 33.347), (-0.045, 33.918),
    (-0.005, 34.278), (0.035, 33.272), (0.075, 34.678), (0.116, 35.065),
    (0.156, 36.014), (0.196, 36.441), (0.236, 38.878), (0.276, 36.328),
    (0.317, 37.844), (0.357, 32.963), (0.397, 35.057), (0.437, 35.193),
    (0.477, 30.902), (0.518, 35.477), (0.558, 36.345), (0.598, 36.056),
    (0.638, 40.56), (0.678, 40.193), (0.719, 36.724), (0.759, 39.845),
    (0.799, 39.749), (0.839, 41.484), (0.879, 39.019), (0.92, 37.805),
    (0.96, 45.267), (1.0, 47.807)
]

x = np.array([p[0] for p in xy])
y = np.array([p[1] for p in xy])

coefs_esperado = [-0.002791, -0.03446, 0.8699, 8.886, 33.1]
y_pred = np.polyval(coefs_esperado, x)

rel_errors = np.abs((y - y_pred) / y)
avg_error = np.mean(rel_errors)
max_error = np.max(rel_errors)
max_error_idx = np.argmax(rel_errors)

print("Polinomio esperado:")
print(f"y = {coefs_esperado[0]:+f} * x^4 {coefs_esperado[1]:+f} * x^3 {coefs_esperado[2]:+f} * x^2 {coefs_esperado[3]:+f} * x + {coefs_esperado[4]:+f}")
print(f"\nError relativo promedio: {avg_error}")
print(f"Error relativo máximo: {max_error}")

coef_ajustado = np.polyfit(x, y, 4)
y_ajustado = np.polyval(coef_ajustado, x)

rel_errors_ajustado = np.abs((y - y_ajustado) / y)
avg_error_ajustado = np.mean(rel_errors_ajustado)
max_error_ajustado = np.max(rel_errors_ajustado)
max_error_idx_ajustado = np.argmax(rel_errors_ajustado)

print("\nPolinomio ajustado (mínimos cuadrados, grado 4):")
for i, c in enumerate(coef_ajustado):
    print(f"{c:+f} * x^{4 - i}")
print(f"\nError relativo promedio del ajustado: {avg_error_ajustado}")
print(f"Error relativo máximo del ajustado: {max_error_ajustado}")

plt.figure(figsize=(12, 6))
plt.plot(x, y, 'o', label='Datos reales')
plt.plot(x, y_pred, '-', label='Polinomio esperado')
plt.plot(x, y_ajustado, '--', label='Polinomio ajustado (grado 4)')
plt.plot(x[max_error_idx_ajustado], y[max_error_idx_ajustado], 'ro', label='Máximo error ajustado')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Comparación de Polinomios')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Polinomio esperado:
# y = -0.002791 * x^4 -0.034460 * x^3 +0.869900 * x^2 +8.886000 * x + +33.100000
#
# Error relativo promedio: 0.055073931857623236
# Error relativo máximo: 0.2187136886424362
#
# Polinomio ajustado (mínimos cuadrados, grado 4):
# -0.012404 * x^4
# -0.139713 * x^3
# +0.599084 * x^2
# +8.905976 * x^1
# +33.017598 * x^0
#
# Error relativo promedio del ajustado: 0.05198204490029517
# Error relativo máximo del ajustado: 0.20983278246037454
